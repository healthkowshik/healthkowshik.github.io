# %%
#| hide
from healthkowshik.core import *

# %% [markdown]
# # healthkowshik.github.io
#
# > Home of Health Kowshik

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install healthkowshik.github.io in Development mode

# %% [markdown]
# ```sh
# # make sure healthkowshik.github.io package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to healthkowshik.github.io
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/healthkowshik/healthkowshik.github.io.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c healthkowshik healthkowshik.github.io
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install healthkowshik.github.io
# ```
#
#
# [repo]: https://github.com/healthkowshik/healthkowshik.github.io
# [docs]: https://healthkowshik.github.io/healthkowshik.github.io/
# [pypi]: https://pypi.org/project/healthkowshik.github.io/
# [conda]: https://anaconda.org/healthkowshik/healthkowshik.github.io

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/healthkowshik/healthkowshik.github.io
# [docs]: https://healthkowshik.github.io/healthkowshik.github.io/
# [pypi]: https://pypi.org/project/healthkowshik.github.io/
# [conda]: https://anaconda.org/healthkowshik/healthkowshik.github.io

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
